# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, FunctionTransformer, OneHotEncoder
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score, make_scorer
from xgboost import XGBClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.decomposition import PCA
import mlflow
import mlflow.sklearn
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin

# %%
file_path = '/Users/rajasaikatukuri/Downloads/pythonproject/breast-cancer.csv'
data = pd.read_csv(file_path)
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
# Data Normalization Process
# Establish SQLite connection
conn = sqlite3.connect("breast_cancer_normalized.db")
cursor = conn.cursor()

# Define the SQL schema for normalization
# Table 1: Patients
cursor.execute("""
CREATE TABLE IF NOT EXISTS Patients (
    PatientID INTEGER PRIMARY KEY,
    Diagnosis TEXT
);
""")

# Table 2: Measurements
cursor.execute("""
CREATE TABLE IF NOT EXISTS Measurements (
    PatientID INTEGER,
    MeasurementType TEXT,
    Value REAL,
    FOREIGN KEY (PatientID) REFERENCES Patients(PatientID)
);
""")

# Insert data into Patients table
patients_data = data[['id', 'diagnosis']].rename(columns={'id': 'PatientID', 'diagnosis': 'Diagnosis'})
patients_data.to_sql('Patients', conn, if_exists='replace', index=False)

# Transform measurements into a long format and insert into Measurements table
measurements = data.drop(columns=['id', 'diagnosis'])
measurements['PatientID'] = data['id']
measurements_long = measurements.melt(
    id_vars=['PatientID'],
    var_name="MeasurementType",
    value_name="Value"
)
measurements_long.to_sql('Measurements', conn, if_exists='replace', index=False)

# Verify data insertion
print("Patients Table:")
print(pd.read_sql_query("SELECT * FROM Patients LIMIT 5;", conn))
print("\nMeasurements Table:")
print(pd.read_sql_query("SELECT * FROM Measurements LIMIT 5;", conn))

# Verify all columns are normalized
print("\nDistinct Measurement Types:")
print(pd.read_sql_query("SELECT DISTINCT MeasurementType FROM Measurements;", conn))

print("\nTotal Rows in Measurements Table:")
print(pd.read_sql_query("SELECT COUNT(*) FROM Measurements;", conn))

#Data Distribution per Column
distribution_query = """
SELECT MeasurementType, COUNT(*) AS Count
FROM Measurements
GROUP BY MeasurementType
ORDER BY MeasurementType;
"""
column_distribution = pd.read_sql_query(distribution_query, conn)
print("\nData Distribution per Column:")
print(column_distribution)

# Data Exploration
# Fetch data for analysis
query = """
SELECT Patients.PatientID, Patients.Diagnosis, Measurements.MeasurementType, Measurements.Value
FROM Patients
JOIN Measurements ON Patients.PatientID = Measurements.PatientID
"""
data_normalized = pd.read_sql_query(query, conn)

# Pivot the data back for exploration
data_pivoted = data_normalized.pivot_table(index='PatientID', columns='MeasurementType', values='Value', aggfunc='mean')
data_pivoted['Diagnosis'] = data_normalized.groupby('PatientID')['Diagnosis'].first()

# Encode target variable
data_pivoted['Diagnosis'] = data_pivoted['Diagnosis'].map({'M': 1, 'B': 0})

# Check for missing values
missing_values = data_pivoted.isnull().sum()
print("\nMissing Values per Column:")
print(missing_values)

# Handle missing values (e.g., fill with mean or drop rows with missing values)
data_pivoted.fillna(data_pivoted.mean(), inplace=True)
print("\nMissing Values after Imputation:")
print(data_pivoted.isnull().sum())
# Out:
# Patients Table:
#    PatientID Diagnosis
# 0     842302         M
# 1     842517         M
# 2   84300903         M
# 3   84348301         M
# 4   84358402         M
#
# Measurements Table:
#    PatientID MeasurementType  Value
# 0     842302     radius_mean  17.99
# 1     842517     radius_mean  20.57
# 2   84300903     radius_mean  19.69
# 3   84348301     radius_mean  11.42
# 4   84358402     radius_mean  20.29
#
# Distinct Measurement Types:
#             MeasurementType
# 0               radius_mean
# 1              texture_mean
# 2            perimeter_mean
# 3                 area_mean
# 4           smoothness_mean
# 5          compactness_mean
# 6            concavity_mean
# 7       concave points_mean
# 8             symmetry_mean
# 9    fractal_dimension_mean
# 10                radius_se
# 11               texture_se
# 12             perimeter_se
# 13                  area_se
# 14            smoothness_se
# 15           compactness_se
# 16             concavity_se
# 17        concave points_se
# 18              symmetry_se
# 19     fractal_dimension_se
# 20             radius_worst
# 21            texture_worst
# 22          perimeter_worst
# 23               area_worst
# 24         smoothness_worst
# 25        compactness_worst
# 26          concavity_worst
# 27     concave points_worst
# 28           symmetry_worst
# 29  fractal_dimension_worst
#
# Total Rows in Measurements Table:
#    COUNT(*)
# 0     17070
#
# Data Distribution per Column:
#             MeasurementType  Count
# 0                 area_mean    569
# 1                   area_se    569
# 2                area_worst    569
# 3          compactness_mean    569
# 4            compactness_se    569
# 5         compactness_worst    569
# 6       concave points_mean    569
# 7         concave points_se    569
# 8      concave points_worst    569
# 9            concavity_mean    569
# 10             concavity_se    569
# 11          concavity_worst    569
# 12   fractal_dimension_mean    569
# 13     fractal_dimension_se    569
# 14  fractal_dimension_worst    569
# 15           perimeter_mean    569
# 16             perimeter_se    569
# 17          perimeter_worst    569
# 18              radius_mean    569
# 19                radius_se    569
# 20             radius_worst    569
# 21          smoothness_mean    569
# 22            smoothness_se    569
# 23         smoothness_worst    569
# 24            symmetry_mean    569
# 25              symmetry_se    569
# 26           symmetry_worst    569
# 27             texture_mean    569
# 28               texture_se    569
# 29            texture_worst    569
#
# Missing Values per Column:
# MeasurementType
# area_mean                  0
# area_se                    0
# area_worst                 0
# compactness_mean           0
# compactness_se             0
# compactness_worst          0
# concave points_mean        0
# concave points_se          0
# concave points_worst       0
# concavity_mean             0
# concavity_se               0
# concavity_worst            0
# fractal_dimension_mean     0
# fractal_dimension_se       0
# fractal_dimension_worst    0
# perimeter_mean             0
# perimeter_se               0
# perimeter_worst            0
# radius_mean                0
# radius_se                  0
# radius_worst               0
# smoothness_mean            0
# smoothness_se              0
# smoothness_worst           0
# symmetry_mean              0
# symmetry_se                0
# symmetry_worst             0
# texture_mean               0
# texture_se                 0
# texture_worst              0
# Diagnosis                  0
# dtype: int64
#
# Missing Values after Imputation:
# MeasurementType
# area_mean                  0
# area_se                    0
# area_worst                 0
# compactness_mean           0
# compactness_se             0
# compactness_worst          0
# concave points_mean        0
# concave points_se          0
# concave points_worst       0
# concavity_mean             0
# concavity_se               0
# concavity_worst            0
# fractal_dimension_mean     0
# fractal_dimension_se       0
# fractal_dimension_worst    0
# perimeter_mean             0
# perimeter_se               0
# perimeter_worst            0
# radius_mean                0
# radius_se                  0
# radius_worst               0
# smoothness_mean            0
# smoothness_se              0
# smoothness_worst           0
# symmetry_mean              0
# symmetry_se                0
# symmetry_worst             0
# texture_mean               0
# texture_se                 0
# texture_worst              0
# Diagnosis                  0
# dtype: int64

# %%
data_pivoted.rename(columns={
    'concave points_mean': 'concave_points_mean',
    'concave points_se': 'concave_points_se',
    'concave points_worst': 'concave_points_worst'
}, inplace=True)

# %%
columns = data_pivoted.columns
print(columns)
# Out:
# Index(['area_mean', 'area_se', 'area_worst', 'compactness_mean',
#        'compactness_se', 'compactness_worst', 'concave_points_mean',
#        'concave_points_se', 'concave_points_worst', 'concavity_mean',
#        'concavity_se', 'concavity_worst', 'fractal_dimension_mean',
#        'fractal_dimension_se', 'fractal_dimension_worst', 'perimeter_mean',
#        'perimeter_se', 'perimeter_worst', 'radius_mean', 'radius_se',
#        'radius_worst', 'smoothness_mean', 'smoothness_se', 'smoothness_worst',
#        'symmetry_mean', 'symmetry_se', 'symmetry_worst', 'texture_mean',
#        'texture_se', 'texture_worst', 'Diagnosis'],
#       dtype='object', name='MeasurementType')

# %%
# Train/Test Split
X = data_pivoted.drop(columns=['Diagnosis'])
y = data_pivoted['Diagnosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train
# Out:
# MeasurementType  area_mean  area_se  area_worst  compactness_mean  \
# PatientID
# 90291                664.7    33.01       758.2           0.06636
# 871642               349.6    21.98       408.3           0.04302
# 923465               361.6    33.00       505.6           0.06602
# 84458202             577.9    50.96       897.0           0.16450
# 851509              1404.0    93.99      2615.0           0.10220
# ...                    ...      ...         ...               ...
# 86211                451.1    24.44       495.2           0.07057
# 924934               321.4    14.46       357.6           0.07658
# 8910499              561.0    26.76       661.5           0.08259
# 9010258              485.8    27.49       547.4           0.10380
# 8811842             1230.0   124.40      2009.0           0.13060
#
# MeasurementType  compactness_se  compactness_worst  concave_points_mean  \
# PatientID
# 90291                   0.01742            0.15810              0.05271
# 871642                  0.01017            0.06791              0.00000
# 923465                  0.01870            0.16330              0.00816
# 84458202                0.03029            0.36820              0.05985
# 851509                  0.01259            0.26000              0.08632
# ...                         ...                ...                  ...
# 86211                   0.01179            0.09358              0.02941
# 924934                  0.02736            0.17100              0.02738
# 8910499                 0.02406            0.17300              0.02142
# 9010258                 0.04235            0.20020              0.04391
# 8811842                 0.03169            0.32350              0.08691
#
# MeasurementType  concave_points_se  concave_points_worst  concavity_mean  ...  \
# PatientID                                                                 ...
# 90291                     0.015760               0.13590         0.08390  ...
# 871642                    0.000000               0.00000         0.00000  ...
# 923465                    0.005917               0.03264         0.01548  ...
# 84458202                  0.014480               0.15560         0.09366  ...
# 851509                    0.010380               0.20090         0.10970  ...
# ...                            ...                   ...             ...  ...
# 86211                     0.015190               0.05882         0.02490  ...
# 924934                    0.017210               0.09127         0.05999  ...
# 8910499                   0.009919               0.06189         0.04072  ...
# 9010258                   0.019660               0.09265         0.10300  ...
# 8811842                   0.017120               0.18200         0.12720  ...
#
# MeasurementType  radius_worst  smoothness_mean  smoothness_se  \
# PatientID
# 90291                   15.79          0.08682       0.008312
# 871642                  11.54          0.08792       0.008713
# 923465                  13.03          0.08192       0.008263
# 84458202                17.06          0.11890       0.008805
# 851509                  29.17          0.09428       0.004728
# ...                       ...              ...            ...
# 86211                   12.83          0.10450       0.005433
# 924934                  10.84          0.09030       0.012050
# 8910499                 14.80          0.07956       0.005436
# 9010258                 13.37          0.08760       0.009853
# 8811842                 25.73          0.09383       0.006804
#
# MeasurementType  smoothness_worst  symmetry_mean  symmetry_se  symmetry_worst  \
# PatientID
# 90291                      0.1312         0.1627      0.01740          0.2477
# 871642                     0.1076         0.1928      0.03265          0.2710
# 923465                     0.1204         0.1976      0.02466          0.3059
# 84458202                   0.1654         0.2196      0.01486          0.3196
# 851509                     0.1401         0.1769      0.01083          0.2822
# ...                           ...            ...          ...             ...
# 86211                      0.1140         0.1900      0.02220          0.2227
# 924934                     0.1384         0.1593      0.01843          0.2226
# 8910499                    0.1005         0.1635      0.02030          0.2446
# 9010258                    0.1096         0.1533      0.02639          0.2121
# 8811842                    0.1353         0.2094      0.01897          0.3070
#
# MeasurementType  texture_mean  texture_se  texture_worst
# PatientID
# 90291                   23.29       1.627          31.71
# 871642                  15.15       1.925          19.20
# 923465                  24.21       1.918          31.45
# 84458202                20.83       1.377          28.14
# 851509                  23.04       1.127          35.59
# ...                       ...         ...            ...
# 86211                   17.84       1.511          20.92
# 924934                  27.61       2.239          34.91
# 8910499                 21.84       1.916          30.04
# 9010258                 19.07       1.478          22.43
# 8811842                 21.56       1.186          28.64
#
# [455 rows x 30 columns]

# %%
# Preprocessor for pipelines
preprocessor = StandardScaler()

# %%
import dagshub
dagshub.init(repo_owner='rajasaikatukuri', repo_name='pythonproject', mlflow=True)
# Out:
# Accessing as rajasaikatukuri
# Initialized MLflow to track repo "rajasaikatukuri/pythonproject"
# Repository rajasaikatukuri/pythonproject initialized!

# %%
experiment 1
# Out:
#   Cell In[10], line 1
#     experiment 1
#                ^
# SyntaxError: invalid syntax

# %%
# MLFlow logging setup
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")
mlflow.set_experiment("Breast Cancer Logistic Regression Experiment 1")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/21b542c67afe4dfda003fecd859e520d', creation_time=1734651988119, experiment_id='5', last_update_time=1734651988119, lifecycle_stage='active', name='Breast Cancer Logistic Regression Experiment 1', tags={}>

# %%
# Experiment 1: Preprocessing pipeline and Logistic Regression with hyperparameter tuning
with mlflow.start_run(run_name="Experiment 1: Preprocessing + Logistic Regression"):
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('minmax', MinMaxScaler()),
        ('log', FunctionTransformer(np.log1p, validate=True)),
        ('clf', LogisticRegression(max_iter=1000, random_state=42))
    ])
    param_grid = {'clf__C': [0.1, 1, 10]}
    grid_search = GridSearchCV(pipeline, param_grid, cv=3, scoring='f1', return_train_score=True)
    grid_search.fit(X_train, y_train)

    best_pipeline = grid_search.best_estimator_
    
    # Cross-validation results
    cv_results = cross_val_score(best_pipeline, X_train, y_train, cv=10, scoring='f1')
    
    # Evaluate F1 score on test data
    y_pred = best_pipeline.predict(X_test)
    test_f1 = f1_score(y_test, y_pred)

    # Log metrics and parameters
    mlflow.log_metric("f1_score_mean", cv_results.mean())
    mlflow.log_metric("f1_score_std", cv_results.std())
    mlflow.log_metric("test_f1_score", test_f1)
    mlflow.log_params(grid_search.best_params_)

    input_example = pd.DataFrame(X_test.iloc[0:1])
    mlflow.sklearn.log_model(best_pipeline, "logistic_regression_pipeline", input_example=input_example)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run Experiment 1: Preprocessing + Logistic Regression at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/5/runs/fdcaf4ad47a94800938ded20b803cb57
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/5

# %%
import joblib

# Save the best pipeline as a .joblib file
joblib.dump(best_pipeline, "/Users/rajasaikatukuri/Downloads/pythonproject/logistic_regression_pipeline.joblib")
print("Model saved as logistic_regression_pipeline.joblib")
# Out:
# Model saved as logistic_regression_pipeline.joblib

# %%
Experiment 2

# %%
# MLFlow logging setup
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")
mlflow.set_experiment("Breast Cancer Multi-Classifier Experiment 2")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/4c9d6bf916b04a7f9ae04cd4e269a48c', creation_time=1734652222649, experiment_id='6', last_update_time=1734652222649, lifecycle_stage='active', name='Breast Cancer Multi-Classifier Experiment 2', tags={}>

# %%
# Experiment 2: Multiple classifiers in a pipeline
classifiers = {
    'LogisticRegression': LogisticRegression(max_iter=1000, random_state=42),
    'RidgeClassifier': RidgeClassifier(random_state=42),
    'RandomForestClassifier': RandomForestClassifier(random_state=42)
}

for name, clf in classifiers.items():
    with mlflow.start_run(run_name=name):
        pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('classifier', clf)
        ])

        # Cross-validation
        cv_scores = cross_val_score(pipeline, X_train, y_train, cv=3, scoring='f1')
        mean_cv_f1 = np.mean(cv_scores)
        std_cv_f1 = np.std(cv_scores)
        mlflow.log_metric("f1_score_mean", mean_cv_f1)
        mlflow.log_metric("f1_score_std", std_cv_f1)

        # Train on full training data
        pipeline.fit(X_train, y_train)

        # Evaluate on test data
        y_pred = pipeline.predict(X_test)
        test_f1 = f1_score(y_test, y_pred)
        mlflow.log_metric("test_f1_score", test_f1)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        mlflow.log_metric("True_Positives", tp)
        mlflow.log_metric("True_Negatives", tn)
        mlflow.log_metric("False_Positives", fp)
        mlflow.log_metric("False_Negatives", fn)

        # Log the model
        mlflow.sklearn.log_model(
            sk_model=pipeline,
            artifact_path="model",
            input_example=X_test.iloc[0].to_dict(),
            registered_model_name=f"{name.replace(' ', '_')}_Pipeline"
        )

# Create a wrapper for XGBClassifier
class SklearnXGBWrapper(BaseEstimator, ClassifierMixin):
    def __init__(self, **kwargs):
        self.model = XGBClassifier(**kwargs)

    def fit(self, X, y):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

    def predict_proba(self, X):
        return self.model.predict_proba(X)

# Train and evaluate XGBClassifier separately
with mlflow.start_run(run_name="XGB Classifier"):
    xgb_wrapper = SklearnXGBWrapper(random_state=42, eval_metric='logloss')

    # Cross-validation
    cv_scores = cross_val_score(xgb_wrapper, X_train, y_train, cv=3, scoring='f1')
    mean_cv_f1 = np.mean(cv_scores)
    std_cv_f1 = np.std(cv_scores)
    mlflow.log_metric("f1_score_mean", mean_cv_f1)
    mlflow.log_metric("f1_score_std", std_cv_f1)

    # Train on full training data
    xgb_wrapper.fit(X_train, y_train)

    # Evaluate on test data
    y_pred = xgb_wrapper.predict(X_test)
    test_f1 = f1_score(y_test, y_pred)
    mlflow.log_metric("test_f1_score", test_f1)

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    mlflow.log_metric("True_Positives", tp)
    mlflow.log_metric("True_Negatives", tn)
    mlflow.log_metric("False_Positives", fp)
    mlflow.log_metric("False_Negatives", fn)

    # Log the model
    mlflow.sklearn.log_model(
        sk_model=xgb_wrapper,
        artifact_path="xgb_model",
        input_example=X_test.iloc[0].to_dict(),
        registered_model_name="XGB_Classifier"
    )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'LogisticRegression_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:31:54 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: LogisticRegression_Pipeline, version 7
# Created version '7' of model 'LogisticRegression_Pipeline'.
# 🏃 View run LogisticRegression at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6/runs/15a71f1b4e144465a0456a3363a17312
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'RidgeClassifier_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:32:16 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RidgeClassifier_Pipeline, version 7
# Created version '7' of model 'RidgeClassifier_Pipeline'.
# 🏃 View run RidgeClassifier at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6/runs/fa0fe8c874084224a7fd1b6432c6e0ed
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'RandomForestClassifier_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:32:38 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier_Pipeline, version 7
# Created version '7' of model 'RandomForestClassifier_Pipeline'.
# 🏃 View run RandomForestClassifier at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6/runs/f87c3f45ba9649d7b6e28c39afffb39f
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'XGB_Classifier' already exists. Creating a new version of this model...
# 2024/12/19 23:33:00 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: XGB_Classifier, version 8
# Created version '8' of model 'XGB_Classifier'.
# 🏃 View run XGB Classifier at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6/runs/55f48d72303746798fe681c212fce06c
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/6

# %%
Experiment 3

# %%
# MLFlow logging setup
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")
mlflow.set_experiment("Breast Cancer Multi-Classifier Experiment 3")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/df0f4247039f4de4ad70d1332290688b', creation_time=1734653003582, experiment_id='7', last_update_time=1734653003582, lifecycle_stage='active', name='Breast Cancer Multi-Classifier Experiment 3', tags={}>

# %%
classifiers = {
    'LogisticRegression': LogisticRegression(max_iter=5000, random_state=42),
    'RidgeClassifier': RidgeClassifier(random_state=42),
    'RandomForestClassifier': RandomForestClassifier(random_state=42)
}

preprocessor = Pipeline([
    ('scaler', StandardScaler())
])

# Add meaningful ratios
X_train['area_to_radius_mean'] = X_train['area_mean'] / X_train['radius_mean']
X_test['area_to_radius_mean'] = X_test['area_mean'] / X_test['radius_mean']

# Polynomial features
X_train['radius_mean_squared'] = X_train['radius_mean'] ** 2
X_test['radius_mean_squared'] = X_test['radius_mean'] ** 2

# Log transformations
X_train['log_area_mean'] = np.log1p(X_train['area_mean'])
X_test['log_area_mean'] = np.log1p(X_test['area_mean'])

# Ensure all integer columns are converted to floats

# %%
print(X_train.columns)
# Out:
# Index(['area_mean', 'area_se', 'area_worst', 'compactness_mean',
#        'compactness_se', 'compactness_worst', 'concave points_mean',
#        'concave points_se', 'concave points_worst', 'concavity_mean',
#        'concavity_se', 'concavity_worst', 'fractal_dimension_mean',
#        'fractal_dimension_se', 'fractal_dimension_worst', 'perimeter_mean',
#        'perimeter_se', 'perimeter_worst', 'radius_mean', 'radius_se',
#        'radius_worst', 'smoothness_mean', 'smoothness_se', 'smoothness_worst',
#        'symmetry_mean', 'symmetry_se', 'symmetry_worst', 'texture_mean',
#        'texture_se', 'texture_worst', 'area_to_radius_mean',
#        'radius_mean_squared', 'log_area_mean'],
#       dtype='object', name='MeasurementType')

# %%
X_train = X_train.astype(float)
X_test = X_test.astype(float)

for name, clf in classifiers.items():
    with mlflow.start_run(run_name=f"Experiment 3: {name}"):
        pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('classifier', clf)
        ])

        # Cross-validation
        cv_scores = cross_val_score(pipeline, X_train, y_train, cv=3, scoring='f1')
        mean_cv_f1 = np.mean(cv_scores)
        std_cv_f1 = np.std(cv_scores)
        mlflow.log_metric("f1_score_mean", mean_cv_f1)
        mlflow.log_metric("f1_score_std", std_cv_f1)

        # Train and evaluate
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)

        test_f1 = f1_score(y_test, y_pred)
        mlflow.log_metric("test_f1_score", test_f1)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        mlflow.log_metric("True_Positives", tp)
        mlflow.log_metric("True_Negatives", tn)
        mlflow.log_metric("False_Positives", fp)
        mlflow.log_metric("False_Negatives", fn)

        input_example = pd.DataFrame(X_test.iloc[0:1])
        mlflow.sklearn.log_model(
            sk_model=pipeline,
            artifact_path="model",
            input_example=input_example.to_dict(orient='records')[0],
            registered_model_name=f"{name}_Pipeline"
        )

# %%
classifiers = {
    'LogisticRegression': LogisticRegression(max_iter=5000, random_state=42),
    'RidgeClassifier': RidgeClassifier(random_state=42),
    'RandomForestClassifier': RandomForestClassifier(random_state=42)
}

preprocessor = Pipeline([
    ('scaler', StandardScaler())
])

for name, clf in classifiers.items():
    with mlflow.start_run(run_name=f"Experiment 3: {name}"):
        # Add meaningful ratios
        X_train['area_to_radius_mean'] = X_train['area_mean'] / X_train['radius_mean']
        X_test['area_to_radius_mean'] = X_test['area_mean'] / X_test['radius_mean']

        # Polynomial features
        X_train['radius_mean_squared'] = X_train['radius_mean'] ** 2
        X_test['radius_mean_squared'] = X_test['radius_mean'] ** 2

        # Log transformations
        X_train['log_area_mean'] = np.log1p(X_train['area_mean'])
        X_test['log_area_mean'] = np.log1p(X_test['area_mean'])

        # Ensure all integer columns are converted to floats
        X_train = X_train.astype(float)
        X_test = X_test.astype(float)

        pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('classifier', clf)
        ])

        # Cross-validation
        cv_scores = cross_val_score(pipeline, X_train, y_train, cv=3, scoring='f1')
        mean_cv_f1 = np.mean(cv_scores)
        std_cv_f1 = np.std(cv_scores)
        mlflow.log_metric("f1_score_mean", mean_cv_f1)
        mlflow.log_metric("f1_score_std", std_cv_f1)

        # Train and evaluate
        pipeline.fit(X_train, y_train)
        y_pred = pipeline.predict(X_test)

        test_f1 = f1_score(y_test, y_pred)
        mlflow.log_metric("test_f1_score", test_f1)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        mlflow.log_metric("True_Positives", tp)
        mlflow.log_metric("True_Negatives", tn)
        mlflow.log_metric("False_Positives", fp)
        mlflow.log_metric("False_Negatives", fn)

        input_example = pd.DataFrame(X_test.iloc[0:1])
        mlflow.sklearn.log_model(
            sk_model=pipeline,
            artifact_path="model",
            input_example=input_example.to_dict(orient='records')[0],
            registered_model_name=f"{name}_Pipeline"
        )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'LogisticRegression_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:34:35 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: LogisticRegression_Pipeline, version 8
# Created version '8' of model 'LogisticRegression_Pipeline'.
# 🏃 View run Experiment 3: LogisticRegression at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/7/runs/9d4fe374f79040e78ad40be355cd8796
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/7
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'RidgeClassifier_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:34:57 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RidgeClassifier_Pipeline, version 8
# Created version '8' of model 'RidgeClassifier_Pipeline'.
# 🏃 View run Experiment 3: RidgeClassifier at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/7/runs/638e3ffbb7a142bf92e38266339519ef
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/7
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'RandomForestClassifier_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:35:19 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestClassifier_Pipeline, version 8
# Created version '8' of model 'RandomForestClassifier_Pipeline'.
# 🏃 View run Experiment 3: RandomForestClassifier at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/7/runs/9c5736fa36b1474dbc0b97643edf711f
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/7

# %%
***Experiment 4***
# Out:
#   Cell In[56], line 1
#     Experiment 4
#                ^
# SyntaxError: invalid syntax

# %%
# MLFlow logging setup
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")
mlflow.set_experiment("Breast Cancer Multi-Classifier Experiment 4")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/a2257e8ff4b34999bbe58ce442426951', creation_time=1734640841930, experiment_id='2', last_update_time=1734640841930, lifecycle_stage='active', name='Breast Cancer Multi-Classifier Experiment 4', tags={}>

# %%
feature_selectors = {
    'VarianceThreshold': VarianceThreshold(threshold=0.1),
    'CorrelationThreshold': None,  # Custom implementation added below
    'FeatureImportance': RandomForestClassifier(random_state=42)
}

for method, selector in feature_selectors.items():
    with mlflow.start_run(run_name=f"Experiment 4: {method}"):
        if method == 'VarianceThreshold':
            selector.fit(X_train)
            X_train_reduced = selector.transform(X_train)
            X_test_reduced = selector.transform(X_test)

        elif method == 'CorrelationThreshold':
            corr_matrix = X_train.corr()
            upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
            highly_corr_features = [column for column in upper_triangle.columns if any(upper_triangle[column] > 0.9)]
            X_train_reduced = X_train.drop(columns=highly_corr_features)
            X_test_reduced = X_test.drop(columns=highly_corr_features)

        elif method == 'FeatureImportance':
            selector.fit(X_train, y_train)
            feature_importances = pd.DataFrame({'feature': X_train.columns, 'importance': selector.feature_importances_})
            selected_features = feature_importances[feature_importances['importance'] > 0.01]['feature']
            X_train_reduced = X_train[selected_features]
            X_test_reduced = X_test[selected_features]

        pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('classifier', LogisticRegression(max_iter=5000, random_state=42))
        ])

        # Cross-validation
        cv_scores = cross_val_score(pipeline, X_train_reduced, y_train, cv=3, scoring='f1')
        mean_cv_f1 = np.mean(cv_scores)
        std_cv_f1 = np.std(cv_scores)
        mlflow.log_metric("f1_score_mean", mean_cv_f1)
        mlflow.log_metric("f1_score_std", std_cv_f1)

        # Train and evaluate
        pipeline.fit(X_train_reduced, y_train)
        y_pred = pipeline.predict(X_test_reduced)

        test_f1 = f1_score(y_test, y_pred)
        mlflow.log_metric("test_f1_score", test_f1)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        mlflow.log_metric("True_Positives", tp)
        mlflow.log_metric("True_Negatives", tn)
        mlflow.log_metric("False_Positives", fp)
        mlflow.log_metric("False_Negatives", fn)

        input_example = pd.DataFrame(X_test_reduced[0:1])
        mlflow.sklearn.log_model(
            sk_model=pipeline,
            artifact_path="model",
            input_example=input_example.to_dict(orient='records')[0],
            registered_model_name=f"FeatureSelection_{method}_Pipeline"
        )
# Out:
# 2024/12/19 23:36:11 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException('The dictionary keys are not all strings.'). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`.
# 2024/12/19 23:36:13 WARNING mlflow.models.model: Failed to validate serving input example {
#   "inputs": {
#     "0": 294.5,
#     "1": 20.05,
#     "2": 366.1,
#     "3": 62.11,
#     "4": 2.132,
#     "5": 68.81,
#     "6": 9.787,
#     "7": 10.92,
#     "8": 19.94,
#     "9": 2.043,
#     "10": 26.29,
#     "11": 30.090936957188106,
#     "12": 95.78536900000002,
#     "13": 5.688668836846153
#   }
# }. Alternatively, you can avoid passing input example and pass model signature instead when logging the model. To ensure the input example is valid prior to serving, please try calling `mlflow.models.validate_serving_input` on the model uri and serving input example. A serving input example can be generated from model input example using `mlflow.models.convert_input_example_to_serving_input` function.
# Got error: float() argument must be a string or a real number, not 'dict'
# Registered model 'FeatureSelection_VarianceThreshold_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:36:19 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: FeatureSelection_VarianceThreshold_Pipeline, version 2
# Created version '2' of model 'FeatureSelection_VarianceThreshold_Pipeline'.
# 🏃 View run Experiment 4: VarianceThreshold at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/2/runs/f917b71c110e4657ae15495888929a57
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/2
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'FeatureSelection_CorrelationThreshold_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:36:42 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: FeatureSelection_CorrelationThreshold_Pipeline, version 2
# Created version '2' of model 'FeatureSelection_CorrelationThreshold_Pipeline'.
# 🏃 View run Experiment 4: CorrelationThreshold at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/2/runs/e6554c9cf4374883a15837a52723b6c0
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/2
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'FeatureSelection_FeatureImportance_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:37:04 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: FeatureSelection_FeatureImportance_Pipeline, version 2
# Created version '2' of model 'FeatureSelection_FeatureImportance_Pipeline'.
# 🏃 View run Experiment 4: FeatureImportance at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/2/runs/2378deeb110f4c6e91d7cc9e2c075d15
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/2

# %%
Experiment 5

# %%
# MLFlow logging setup
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")
mlflow.set_experiment("Breast Cancer Multi-Classifier Experiment 5")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/edcb42e9397b4e14b9c33fadbca3da04', creation_time=1734645062784, experiment_id='3', last_update_time=1734645062784, lifecycle_stage='active', name='Breast Cancer Multi-Classifier Experiment 5', tags={}>

# %%
# Experiment 5: PCA for dimensionality reduction
with mlflow.start_run(run_name="Experiment 5: PCA"):
    # PCA implementation
    pca = PCA()
    pca.fit(X_train)

    # Scree plot
    plt.figure(figsize=(10, 6))
    plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
    plt.title('Scree Plot')
    plt.xlabel('Number of Components')
    plt.ylabel('Cumulative Explained Variance')
    plt.grid(True)
    scree_plot_path = "scree_plot.png"
    plt.savefig(scree_plot_path)
    mlflow.log_artifact(scree_plot_path)

    # PCA transformation
    n_components = np.argmax(np.cumsum(pca.explained_variance_ratio_) >= 0.95) + 1
    pca = PCA(n_components=n_components, random_state=42)
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)

    pipeline = Pipeline([
        ('classifier', LogisticRegression(max_iter=5000, random_state=42))
    ])

    # Cross-validation
    cv_scores = cross_val_score(pipeline, X_train_pca, y_train, cv=3, scoring='f1')
    mean_cv_f1 = np.mean(cv_scores)
    std_cv_f1 = np.std(cv_scores)
    mlflow.log_metric("f1_score_mean", mean_cv_f1)
    mlflow.log_metric("f1_score_std", std_cv_f1)

    # Train and evaluate
    pipeline.fit(X_train_pca, y_train)
    y_pred = pipeline.predict(X_test_pca)

    test_f1 = f1_score(y_test, y_pred)
    mlflow.log_metric("test_f1_score", test_f1)

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    mlflow.log_metric("True_Positives", tp)
    mlflow.log_metric("True_Negatives", tn)
    mlflow.log_metric("False_Positives", fp)
    mlflow.log_metric("False_Negatives", fn)

    input_example = pd.DataFrame(X_test_pca[0:1])
    mlflow.sklearn.log_model(
        sk_model=pipeline,
        artifact_path="pca_model",
        input_example=input_example.to_dict(orient='records')[0],
        registered_model_name="PCA_LogisticRegression_Pipeline"
    )
# Out:
# 2024/12/19 23:38:22 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException('The dictionary keys are not all strings.'). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`.
# 2024/12/19 23:38:24 WARNING mlflow.models.model: Failed to validate serving input example {
#   "inputs": {
#     "0": -654.1099731279539
#   }
# }. Alternatively, you can avoid passing input example and pass model signature instead when logging the model. To ensure the input example is valid prior to serving, please try calling `mlflow.models.validate_serving_input` on the model uri and serving input example. A serving input example can be generated from model input example using `mlflow.models.convert_input_example_to_serving_input` function.
# Got error: Expected 2D array, got scalar array instead:
# array={'0': array(-654.10997313)}.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# Registered model 'PCA_LogisticRegression_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:38:31 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: PCA_LogisticRegression_Pipeline, version 2
# Created version '2' of model 'PCA_LogisticRegression_Pipeline'.
# 🏃 View run Experiment 5: PCA at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/3/runs/dad9e02d83474f8080e855e746de706b
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/3

# %%
**experiment 6**
# Out:
#   Cell In[150], line 1
#     **experiment 6**
#     ^
# SyntaxError: invalid syntax

# %%
# MLFlow logging setup
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")
mlflow.set_experiment("Breast Cancer Multi-Classifier Experiment 6")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/fd7ad81c215c4e3696df46d8dd67d3fa', creation_time=1734646168409, experiment_id='4', last_update_time=1734646168409, lifecycle_stage='active', name='Breast Cancer Multi-Classifier Experiment 6', tags={}>

# %%
# Experiment 6: Custom Experiment - Gradient Boosting with Hyperparameter Tuning
with mlflow.start_run(run_name="Experiment 6: Gradient Boosting"):
    from sklearn.ensemble import GradientBoostingClassifier
    from sklearn.model_selection import GridSearchCV

    # Define Gradient Boosting Classifier
    gbc = GradientBoostingClassifier(random_state=42)

    # Define hyperparameter grid
    param_grid = {
        'n_estimators': [50, 100, 150],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 4, 5]
    }

    # Grid Search for hyperparameter tuning
    grid_search = GridSearchCV(estimator=gbc, param_grid=param_grid, scoring='f1', cv=3, verbose=1, n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Best model from Grid Search
    best_model = grid_search.best_estimator_


    # Cross-validation scores for the best model
    cv_scores = cross_val_score(best_model, X_train, y_train, cv=3, scoring='f1')
    mean_cv_f1 = np.mean(cv_scores)
    std_cv_f1 = np.std(cv_scores)
    mlflow.log_metric("f1_score_mean", mean_cv_f1)
    mlflow.log_metric("f1_score_std", std_cv_f1)

    # Train and evaluate on test data
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)

    test_f1 = f1_score(y_test, y_pred)
    mlflow.log_metric("test_f1_score", test_f1)

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    mlflow.log_metric("True_Positives", tp)
    mlflow.log_metric("True_Negatives", tn)
    mlflow.log_metric("False_Positives", fp)
    mlflow.log_metric("False_Negatives", fn)

    input_example = pd.DataFrame(X_test[0:1])
    mlflow.sklearn.log_model(
        sk_model=best_model,
        artifact_path="gradient_boosting_model",
        input_example=input_example.to_dict(orient='records')[0],
        registered_model_name="Gradient_Boosting_Classifier"
    )
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'Gradient_Boosting_Classifier' already exists. Creating a new version of this model...
# 2024/12/19 23:44:27 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Gradient_Boosting_Classifier, version 3
# Created version '3' of model 'Gradient_Boosting_Classifier'.
# 🏃 View run Experiment 6: Gradient Boosting at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/4/runs/bfa54587cb944650b59f19ebe413526d
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/4

# %%
Experiment 7

# %%
# MLFlow logging setup
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")
mlflow.set_experiment("Breast Cancer Multi-Classifier Experiment 7")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/ada73e731a6649dead100f4cecdee9df', creation_time=1734668107119, experiment_id='8', last_update_time=1734668107119, lifecycle_stage='active', name='Breast Cancer Multi-Classifier Experiment 7', tags={}>

# %%
# Experiment 7: Custom Experiment - Stacking Classifier
with mlflow.start_run(run_name="Experiment 7: Stacking Classifier"):
    from sklearn.ensemble import StackingClassifier

    # Define base models and meta-classifier
    base_models = [
        ('lr', LogisticRegression(max_iter=5000, random_state=42)),
        ('rf', RandomForestClassifier(random_state=42)),
        ('ridge', RidgeClassifier(random_state=42))
    ]
    meta_classifier = LogisticRegression(max_iter=5000, random_state=42)

    # Create StackingClassifier
    stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_classifier, cv=3)

    # Preprocessing and pipeline
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('stacking', stacking_clf)
    ])

    # Cross-validation
    cv_scores = cross_val_score(pipeline, X_train, y_train, cv=3, scoring='f1')
    mean_cv_f1 = np.mean(cv_scores)
    std_cv_f1 = np.std(cv_scores)
    mlflow.log_metric("f1_score_mean", mean_cv_f1)
    mlflow.log_metric("f1_score_std", std_cv_f1)

    # Train and evaluate
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)

    test_f1 = f1_score(y_test, y_pred)
    mlflow.log_metric("test_f1_score", test_f1)

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    mlflow.log_metric("True_Positives", tp)
    mlflow.log_metric("True_Negatives", tn)
    mlflow.log_metric("False_Positives", fp)
    mlflow.log_metric("False_Negatives", fn)

    input_example = pd.DataFrame(X_test[0:1])
    mlflow.sklearn.log_model(
        sk_model=pipeline,
        artifact_path="stacking_model",
        input_example=input_example.to_dict(orient='records')[0],
        registered_model_name="Stacking_Classifier_Pipeline"
    )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/types/utils.py:435: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'Stacking_Classifier_Pipeline' already exists. Creating a new version of this model...
# 2024/12/19 23:45:42 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Stacking_Classifier_Pipeline, version 2
# Created version '2' of model 'Stacking_Classifier_Pipeline'.
# 🏃 View run Experiment 7: Stacking Classifier at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/8/runs/48e08856b8034e2386ef2a16073bfeef
# 🧪 View experiment at: https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/#/experiments/8

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

# Set MLFlow tracking URI
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")

# Initialize MLFlow client
client = mlflow.tracking.MlflowClient()

# Fetch all experiments using search_experiments
experiments = client.search_experiments()

# Collect test_f1_score for all experiments
f1_scores = []
for experiment in experiments:
    experiment_name = experiment.name
    runs = client.search_runs(experiment.experiment_id)
    for run in runs:
        test_f1 = run.data.metrics.get("test_f1_score")
        if test_f1 is not None:
            f1_scores.append({"Experiment": experiment_name, "Test F1 Score": test_f1})

# Convert collected data to a DataFrame
f1_df = pd.DataFrame(f1_scores)

# Plot the Test F1 Scores across all experiments
plt.figure(figsize=(12, 6))
for experiment_name in f1_df['Experiment'].unique():
    subset = f1_df[f1_df['Experiment'] == experiment_name]
    plt.bar(subset.index, subset['Test F1 Score'], label=experiment_name)

plt.title('Test F1 Scores Across MLFlow Experiments')
plt.ylabel('Test F1 Score')
plt.xlabel('Experiments and Runs')
plt.xticks(ticks=range(len(f1_df)), labels=f1_df['Experiment'], rotation=45)
plt.legend(title='Experiment Names')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

# Set MLFlow tracking URI
mlflow.set_tracking_uri("https://dagshub.com/rajasaikatukuri/pythonproject.mlflow")

# Initialize MLFlow client
client = mlflow.tracking.MlflowClient()

# Fetch all experiments using search_experiments
experiments = client.search_experiments()

# Collect test_f1_score for all experiments
f1_scores = []
for experiment in experiments:
    experiment_name = experiment.name
    runs = client.search_runs(experiment.experiment_id)
    for run in runs:
        test_f1 = run.data.metrics.get("test_f1_score")
        if test_f1 is not None:
            f1_scores.append({
                "Experiment": experiment_name,
                "Run ID": run.info.run_id,
                "Test F1 Score": test_f1
            })

# Convert collected data to a DataFrame
f1_df = pd.DataFrame(f1_scores)

# Find the best model based on the highest Test F1 Score
best_model = f1_df.loc[f1_df['Test F1 Score'].idxmax()]

print("Best Model Details:")
print(best_model)

# Plot the Test F1 Scores across all experiments
plt.figure(figsize=(12, 6))
for experiment_name in f1_df['Experiment'].unique():
    subset = f1_df[f1_df['Experiment'] == experiment_name]
    plt.bar(subset.index, subset['Test F1 Score'], label=experiment_name)

plt.title('Test F1 Scores Across MLFlow Experiments')
plt.ylabel('Test F1 Score')
plt.xlabel('Experiments and Runs')
plt.xticks(ticks=range(len(f1_df)), labels=f1_df['Experiment'], rotation=45)
plt.legend(title='Experiment Names')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Best Model Details:
# Experiment       Breast Cancer Multi-Classifier Experiment 3
# Run ID                      9d4fe374f79040e78ad40be355cd8796
# Test F1 Score                                       0.987952
# Name: 3, dtype: object

# %%
import joblib
import mlflow

# Load the model from the best run in MLFlow
model_uri = f"runs:/b1093160afee4e17bd104bb90fe85c72/model"
model = mlflow.pyfunc.load_model(model_uri)

# Save the model as a joblib file
joblib.dump(model, "/Users/rajasaikatukuri/Downloads/pythonproject/final_model.pkl")
print("Model saved as 'final_model.joblib'")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[20], line 6
#       4 # Load the model from the best run in MLFlow
#       5 model_uri = f"runs:/b1093160afee4e17bd104bb90fe85c72/model"
# ----> 6 model = mlflow.pyfunc.load_model(model_uri)
#       8 # Save the model as a joblib file
#       9 joblib.dump(model, "/Users/rajasaikatukuri/Downloads/pythonproject/final_model.pkl")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/tracing/provider.py:309, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     307 disable()
#     308 try:
# --> 309     is_func_called, result = True, f(*args, **kwargs)
#     310 finally:
#     311     enable()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/pyfunc/__init__.py:1033, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1029         entity_list.append(Entity(job=job_entity))
#    1031     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1033 local_path = _download_artifact_from_uri(
#    1034     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1035 )
#    1037 if not suppress_warnings:
#    1038     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/tracking/artifact_utils.py:116, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
# --> 116 return repo.download_artifacts(artifact_path=artifact_path, dst_path=output_path)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/store/artifact/runs_artifact_repo.py:131, in RunsArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     114 def download_artifacts(self, artifact_path, dst_path=None):
#     115     """
#     116     Download an artifact file or directory to a local directory if applicable, and return a
#     117     local path for it.
#    (...)
#     129         Absolute path of the local filesystem location containing the desired artifacts.
#     130     """
# --> 131     return self.repo.download_artifacts(artifact_path, dst_path)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mlflow/store/artifact/artifact_repo.py:302, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     296         template = "##### File {path} #####\n{error}"
#     298     failures = "\n".join(
#     299         template.format(path=path, error=error, traceback=tracebacks[path])
#     300         for path, error in failed_downloads.items()
#     301     )
# --> 302     raise MlflowException(
#     303         message=(
#     304             "The following failures occurred while downloading one or more"
#     305             f" artifacts from {self.artifact_uri}:\n{_truncate_error(failures)}"
#     306         )
#     307     )
#     309 return os.path.join(dst_path, artifact_path)
#
# MlflowException: The following failures occurred while downloading one or more artifacts from https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/api/2.0/mlflow-artifacts/artifacts/21b542c67afe4dfda003fecd859e520d/b1093160afee4e17bd104bb90fe85c72/artifacts:
# ##### File model #####
# API request to https://dagshub.com/rajasaikatukuri/pythonproject.mlflow/api/2.0/mlflow-artifacts/artifacts/21b542c67afe4dfda003fecd859e520d/b1093160afee4e17bd104bb90fe85c72/artifacts/model failed with exception HTTPSConnectionPool(host='dagshub.com', port=443): Max retries exceeded with url: /rajasaikatukuri/pythonproject.mlflow/api/2.0/mlflow-artifacts/artifacts/21b542c67afe4dfda003fecd859e520d/b1093160afee4e17bd104bb90fe85c72/artifacts/model (Caused by ResponseError('too many 500 error responses'))
